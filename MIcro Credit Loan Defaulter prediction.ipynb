# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
loan=pd.read_csv("microcredit.csv")
loan
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
loan.drop("Unnamed: 0",axis=1,inplace=True)
loan
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
loan.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %%
loan.isnull().sum().sum()
# Out:
# 0

# %%
loan[loan.duplicated()]
# Out:
#         label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 198194      1  82741I90849  367.0   3136.666667   3136.666667   3320.95
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 198194   3320.95                1.0                0.0               770  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 198194              6.0                 0.0          4.0            24
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 198194                6                 0.0      42.75      42.75      UPW
#
#              pdate
# 198194  2016-07-23
#
# [1 rows x 36 columns]

# %%
loan.drop_duplicates(keep='first',inplace=True)

# %%
loan.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209592.000000  209592.000000  209592.000000  209592.000000
# mean        0.875177    8112.380399    5381.412999    6082.529123
# std         0.330519   75696.261220    9220.644093   10918.836919
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.439500      42.691917
# 50%         1.000000     527.000000    1469.091833    1500.000000
# 75%         1.000000     982.000000    7244.096000    7802.795000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209592.000000  209592.000000      209592.000000      209592.000000
# mean     2692.578912    3483.407309        3755.865715        3712.220632
# std      4308.596841    5770.475034       53906.020204       53374.960145
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
loan.describe(include=['object','datetime'])
# Out:
#              msisdn pcircle       pdate
# count        209592  209592      209592
# unique       186243       1          82
# top     04581I85330     UPW  2016-07-04
# freq              7  209592        3150

# %%
for column in loan.columns:
    if loan[column].dtype==object:
        print(str(column) + ':' + str(loan[column].unique()))
        print(loan[column].value_counts())
        print('_____________________________________________')
# Out:
# msisdn:['21408I70789' '76462I70374' '17943I70372' ... '22758I85348' '59712I82733'
#  '65061I85339']
# 04581I85330    7
# 47819I90840    7
# 43430I70786    6
# 55809I89238    6
# 67324I84453    6
#               ..
# 28720I90840    1
# 36902I90840    1
# 17447I88689    1
# 59686I90584    1
# 65061I85339    1
# Name: msisdn, Length: 186243, dtype: int64
# _____________________________________________
# pcircle:['UPW']
# UPW    209592
# Name: pcircle, dtype: int64
# _____________________________________________
# pdate:['2016-07-20' '2016-08-10' '2016-08-19' '2016-06-06' '2016-06-22'
#  '2016-07-02' '2016-07-05' '2016-08-05' '2016-06-15' '2016-06-08'
#  '2016-06-12' '2016-06-20' '2016-06-29' '2016-06-16' '2016-08-03'
#  '2016-06-24' '2016-07-04' '2016-07-03' '2016-07-01' '2016-08-08'
#  '2016-06-26' '2016-06-23' '2016-07-06' '2016-07-09' '2016-06-10'
#  '2016-06-07' '2016-06-27' '2016-08-11' '2016-06-30' '2016-06-19'
#  '2016-07-26' '2016-08-14' '2016-06-14' '2016-06-21' '2016-06-25'
# ...

# %%
for column in loan.columns:
    if loan[column].dtype==np.number:
        print(str(column) + ' : ' + str(loan[column].nunique()))
        print(loan[column].nunique())
        print('______________________________________________________________________')
# Out:
# aon : 4507
# 4507
# ______________________________________________________________________
# daily_decr30 : 147025
# 147025
# ______________________________________________________________________
# daily_decr90 : 158669
# 158669
# ______________________________________________________________________
# rental30 : 132148
# 132148
# ______________________________________________________________________
# rental90 : 141033
# 141033
# ______________________________________________________________________
# last_rech_date_ma : 1186
# 1186
# ______________________________________________________________________
# last_rech_date_da : 1174
# 1174
# ______________________________________________________________________
# fr_ma_rech30 : 1083
# 1083
# ______________________________________________________________________
# sumamnt_ma_rech30 : 15141
# 15141
# ______________________________________________________________________
# medianamnt_ma_rech30 : 510
# 510
# ...

# %%
unique = loan.nunique()
unique = unique[unique.values == 1]
unique
# Out:
# pcircle    1
# dtype: int64

# %%
numerical_feature = [feature for feature in loan.columns if loan[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(loan[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in loan.columns if feature not in numerical_feature]
print("Numerical Features Count {}".format(len(numerical_feature)))
print("Discrete feature Count {}".format(len(discrete_feature)))
print("Continuous feature Count {}".format(len(continuous_feature)))
print("Categorical feature Count {}".format(len(categorical_feature)))
# Out:
# Numerical Features Count 33
# Discrete feature Count 4
# Continuous feature Count 29
# Categorical feature Count 3

# %%
loan["pday"]=loan['pdate'].str.split('-').str[2].astype(int)
loan["pmonth"]=loan['pdate'].str.split('-').str[1].astype(int)
loan["pyear"]=loan['pdate'].str.split('-').str[0].astype(int)
loan.drop(["pdate"],axis=1,inplace=True)
loan
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
loan.drop(['pcircle'],axis=1,inplace=True)
loan
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
loan.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166151
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166151  0.000374      0.977704      1.000000
# rental30              0.058084 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131805  0.004256      0.275837      0.264130
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426708
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141491  0.004306      0.295356      0.282959
# ...

# %%
loan.corr()['label'].sort_values()
# Out:
# fr_da_rech90           -0.005418
# medianmarechprebal30   -0.004829
# aon                    -0.003785
# fr_da_rech30           -0.000026
# maxamnt_loans30         0.000248
# fr_ma_rech30            0.001330
# last_rech_date_da       0.001711
# cnt_da_rech90           0.002999
# last_rech_date_ma       0.003728
# cnt_da_rech30           0.003827
# cnt_loans90             0.004733
# pday                    0.006824
# medianamnt_loans90      0.035747
# medianmarechprebal90    0.039300
# medianamnt_loans30      0.044590
# payback30               0.048330
# payback90               0.049178
# rental30                0.058084
# rental90                0.075521
# maxamnt_loans90         0.084144
# fr_ma_rech90            0.084386
# medianamnt_ma_rech90    0.120855
# last_rech_amt_ma        0.131805
# medianamnt_ma_rech30    0.141491
# pmonth                  0.154948
# daily_decr90            0.166151
# daily_decr30            0.168298
# cnt_loans30             0.196283
# ...

# %%
loan_corr=loan.corr()
plt.figure(figsize=(40,30))
sns.heatmap(loan_corr,vmin=-1,vmax=1,annot=True,center=0,fmt='.2g',linewidth=0.1)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
loan.drop(['daily_decr30','rental30','amnt_loans30','payback30'],axis=1,inplace=True)
loan
# Out:
#         label       msisdn     aon  daily_decr90  rental90  last_rech_date_ma  \
# 0           0  21408I70789   272.0   3065.150000    260.13                2.0
# 1           1  76462I70374   712.0  12124.750000   3691.26               20.0
# 2           1  17943I70372   535.0   1398.000000    900.13                3.0
# 3           1  55773I70781   241.0     21.228000    159.42               41.0
# 4           1  03813I82730   947.0    150.619333   1098.90                4.0
# ...       ...          ...     ...           ...       ...                ...
# 209588      1  22758I85348   404.0    151.872333   1089.19                1.0
# 209589      1  95583I84455  1075.0     36.936000   1728.36                4.0
# 209590      1  28556I85350  1013.0  11904.350000   8893.20                3.0
# 209591      1  59712I82733  1732.0  12574.370000    984.58                2.0
# 209592      1  65061I85339  1581.0   4534.820000    631.20               13.0
#
# ...

# %%
plt.figure(figsize=(16,8))
loan.corr()['label'].sort_values(ascending=False).drop(['label']).plot(kind='bar',color='blue',edgecolor='red',grid=True)
plt.xlabel('Feature',fontsize=14,color='b')
plt.ylabel('column with target names', fontsize=14,color='g')
plt.title('correlation',fontsize=18,color='r')
plt.show()

# %%
loan.plot(kind='density',subplots=True, layout=(10,4), sharex=False,legend=False,fontsize=1,figsize=(18,18))
plt.show()

# %%
sns.countplot(x='label', data=loan, palette='cubehelix')
plt.title('"0" for defaulter & "1" for non defaulter',fontsize=16)
plt.show()
print(loan['label'].value_counts())
# Out:
# 1    183430
# 0     26162
# Name: label, dtype: int64

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='pday',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='pday', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='pmonth',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='pmonth', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='pyear',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='pyear', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='cnt_ma_rech30',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='cnt_ma_rech90',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='aon',hue='label',data=loan,palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='aon', ylabel='count'>

# %%
loan.iloc[:,0:17].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loan.iloc[:,17:34].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loan.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr90            float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# ...

# %%
IQR=loan.aon.quantile(0.75)-loan.aon.quantile(0.25)
lower_bridge=loan.aon.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.aon.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -858.0 2086.0

# %%
loan.loc[loan['aon']>=2086.0,'aon']=2086.0 
loan.loc[loan['aon']<=-858.0,'aon']=-858.0

# %%
IQR=loan.daily_decr90.quantile(0.75)-loan.daily_decr90.quantile(0.25)
lower_bridge=loan.daily_decr90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.daily_decr90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -11597.462708333342 19442.949625000016

# %%
loan.loc[loan['daily_decr90']>=19442.949625000016,'daily_decr90']=19442.949625000016
loan.loc[loan['daily_decr90']<=-11597.462708333342,'daily_decr90']=-11597.462708333342

# %%
IQR=loan.rental90.quantile(0.75)-loan.rental90.quantile(0.25)
lower_bridge=loan.rental90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.rental90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5552.038749999999 10054.091249999998

# %%
loan.loc[loan['rental90']>=10054.091249999998,'rental90']=10054.091249999998
loan.loc[loan['rental90']<=-5552.038749999999,'rental90']=-5552.038749999999

# %%
IQR=loan.last_rech_date_ma.quantile(0.75)-loan.last_rech_date_ma.quantile(0.25)
lower_bridge=loan.last_rech_date_ma.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.last_rech_date_ma.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -8.0 16.0

# %%
loan.loc[loan['last_rech_date_ma']>=16.0,'last_rech_date_ma']=16.0 
loan.loc[loan['last_rech_date_ma']<=-8.0,'last_rech_date_ma']=-8.0

# %%
IQR=loan.last_rech_amt_ma.quantile(0.75)-loan.last_rech_amt_ma.quantile(0.25)
lower_bridge=loan.last_rech_amt_ma.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.last_rech_amt_ma.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -1538.5 4617.5

# %%
loan.loc[loan['last_rech_amt_ma']>=4617.5,'last_rech_amt_da']=4617.5 
loan.loc[loan['last_rech_amt_ma']<=-1538.5,'last_rech_amt_ma']=-1538.5

# %%
IQR=loan.fr_ma_rech30.quantile(0.75)-loan.fr_ma_rech30.quantile(0.25)
lower_bridge=loan.fr_ma_rech30.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.fr_ma_rech30.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -9.0 15.0

# %%
loan.loc[loan['fr_ma_rech30']>=15.0,'fr_ma_rech30']=15.0
loan.loc[loan['fr_ma_rech30']<=-9.0,'fr_ma_rech30']=-9.0

# %%
IQR=loan.sumamnt_ma_rech30.quantile(0.75)-loan.sumamnt_ma_rech30.quantile(0.25)
lower_bridge=loan.sumamnt_ma_rech30.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.sumamnt_ma_rech30.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -11165.0 22715.0

# %%
loan.loc[loan['sumamnt_ma_rech30']>=22715.0,'sumamnt_ma_rech30']=22715.0
loan.loc[loan['sumamnt_ma_rech30']<=-11165.0,'sumamnt_ma_rech30']=-11165.0

# %%
IQR=loan.medianamnt_ma_rech30.quantile(0.75)-loan.medianamnt_ma_rech30.quantile(0.25)
lower_bridge=loan.medianamnt_ma_rech30.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.medianamnt_ma_rech30.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -961.0 3655.0

# %%
loan.loc[loan['medianamnt_ma_rech30']>=3655.0,'medianamnt_ma_rech30']=3655.0
loan.loc[loan['medianamnt_ma_rech30']<=-961.0,'medianamnt_ma_rech30']=-961.0

# %%
IQR=loan.cnt_ma_rech90.quantile(0.75)-loan.cnt_ma_rech90.quantile(0.25)
lower_bridge=loan.cnt_ma_rech90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.cnt_ma_rech90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -7.0 17.0

# %%
loan.loc[loan['cnt_ma_rech90']>=17.0,'cnt_ma_rech90']=17.0
loan.loc[loan['cnt_ma_rech90']<=-7.0,'cnt_ma_rech90']=-7.0

# %%
IQR=loan.fr_ma_rech90.quantile(0.75)-loan.fr_ma_rech90.quantile(0.25)
lower_bridge=loan.fr_ma_rech90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.fr_ma_rech90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -12.0 20.0

# %%
loan.loc[loan['fr_ma_rech90']>=20.0,'fr_ma_rech90']=20.0
loan.loc[loan['fr_ma_rech90']<=-12.0,'fr_ma_rech90']=-12.0

# %%
IQR=loan.sumamnt_ma_rech90.quantile(0.75)-loan.sumamnt_ma_rech90.quantile(0.25)
lower_bridge=loan.sumamnt_ma_rech90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.sumamnt_ma_rech90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -18207.5 36524.5

# %%
loan.loc[loan['sumamnt_ma_rech90']>=36524.5,'sumamnt_ma_rech90']=36524.5
loan.loc[loan['sumamnt_ma_rech90']<=-18207.5,'sumamnt_ma_rech90']=-18207.5

# %%
IQR=loan.medianamnt_ma_rech90.quantile(0.75)-loan.medianamnt_ma_rech90.quantile(0.25)
lower_bridge=loan.medianamnt_ma_rech90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.medianamnt_ma_rech90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -953.5 3650.5

# %%
loan.loc[loan['medianamnt_ma_rech90']>=3650.5,'medianamnt_ma_rech90']=3650.5
loan.loc[loan['medianamnt_ma_rech90']<=-953.5,'medianamnt_ma_rech90']=-953.5

# %%
IQR=loan.medianmarechprebal90.quantile(0.75)-loan.medianmarechprebal90.quantile(0.25)
lower_bridge=loan.medianmarechprebal90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.medianmarechprebal90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -82.46499999999973 176.3749999999998

# %%
loan.loc[loan['medianmarechprebal90']>=176.3749999999998,'medianmarechprebal90']=176.3749999999998
loan.loc[loan['medianmarechprebal90']<=-82.46499999999973,'medianmarechprebal90']=-82.46499999999973

# %%
IQR=loan.cnt_loans90.quantile(0.75)-loan.cnt_loans90.quantile(0.25)
lower_bridge=loan.cnt_loans90.quantile(0.25)-(IQR*1.5)
upper_bridge=loan.cnt_loans90.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5.0 11.0

# %%
loan.loc[loan['cnt_loans90']>=11.0,'cnt_loans90']=11.0
loan.loc[loan['cnt_loans90']<=-5.0,'cnt_loans90']=-5.0

# %%
loan.iloc[:,0:17].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loan.iloc[:,17:34].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
loan.shape
# Out:
# (209592, 34)

# %%
loan
# Out:
#         label       msisdn     aon  daily_decr90  rental90  last_rech_date_ma  \
# 0           0  21408I70789   272.0   3065.150000    260.13                2.0
# 1           1  76462I70374   712.0  12124.750000   3691.26               16.0
# 2           1  17943I70372   535.0   1398.000000    900.13                3.0
# 3           1  55773I70781   241.0     21.228000    159.42               16.0
# 4           1  03813I82730   947.0    150.619333   1098.90                4.0
# ...       ...          ...     ...           ...       ...                ...
# 209588      1  22758I85348   404.0    151.872333   1089.19                1.0
# 209589      1  95583I84455  1075.0     36.936000   1728.36                4.0
# 209590      1  28556I85350  1013.0  11904.350000   8893.20                3.0
# 209591      1  59712I82733  1732.0  12574.370000    984.58                2.0
# 209592      1  65061I85339  1581.0   4534.820000    631.20               13.0
#
# ...

# %%
loan.drop(['last_rech_amt_da'],axis=1,inplace=True)
loan.shape
# Out:
# (209592, 33)

# %%
loan
# Out:
#         label       msisdn     aon  daily_decr90  rental90  last_rech_date_ma  \
# 0           0  21408I70789   272.0   3065.150000    260.13                2.0
# 1           1  76462I70374   712.0  12124.750000   3691.26               16.0
# 2           1  17943I70372   535.0   1398.000000    900.13                3.0
# 3           1  55773I70781   241.0     21.228000    159.42               16.0
# 4           1  03813I82730   947.0    150.619333   1098.90                4.0
# ...       ...          ...     ...           ...       ...                ...
# 209588      1  22758I85348   404.0    151.872333   1089.19                1.0
# 209589      1  95583I84455  1075.0     36.936000   1728.36                4.0
# 209590      1  28556I85350  1013.0  11904.350000   8893.20                3.0
# 209591      1  59712I82733  1732.0  12574.370000    984.58                2.0
# 209592      1  65061I85339  1581.0   4534.820000    631.20               13.0
#
# ...

# %%
loan.drop('msisdn',axis=1,inplace=True)
loan.shape
# Out:
# (209592, 32)

# %%
loan
# Out:
#         label     aon  daily_decr90  rental90  last_rech_date_ma  \
# 0           0   272.0   3065.150000    260.13                2.0
# 1           1   712.0  12124.750000   3691.26               16.0
# 2           1   535.0   1398.000000    900.13                3.0
# 3           1   241.0     21.228000    159.42               16.0
# 4           1   947.0    150.619333   1098.90                4.0
# ...       ...     ...           ...       ...                ...
# 209588      1   404.0    151.872333   1089.19                1.0
# 209589      1  1075.0     36.936000   1728.36                4.0
# 209590      1  1013.0  11904.350000   8893.20                3.0
# 209591      1  1732.0  12574.370000    984.58                2.0
# 209592      1  1581.0   4534.820000    631.20               13.0
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                     0.0            1539.0              2          15.0
# ...

# %%
x=loan.drop('label',axis=1)
y=loan['label']

# %%
x
# Out:
#            aon  daily_decr90  rental90  last_rech_date_ma  last_rech_date_da  \
# 0        272.0   3065.150000    260.13                2.0                0.0
# 1        712.0  12124.750000   3691.26               16.0                0.0
# 2        535.0   1398.000000    900.13                3.0                0.0
# 3        241.0     21.228000    159.42               16.0                0.0
# 4        947.0    150.619333   1098.90                4.0                0.0
# ...        ...           ...       ...                ...                ...
# 209588   404.0    151.872333   1089.19                1.0                0.0
# 209589  1075.0     36.936000   1728.36                4.0                0.0
# 209590  1013.0  11904.350000   8893.20                3.0                0.0
# 209591  1732.0  12574.370000    984.58                2.0               38.0
# 209592  1581.0   4534.820000    631.20               13.0                0.0
#
# ...

# %%
x.shape
# Out:
# (209592, 31)

# %%
y.shape
# Out:
# (209592,)

# %%
x.skew()
# Out:
# aon                      0.947120
# daily_decr90             1.238989
# rental90                 1.193292
# last_rech_date_ma        1.040294
# last_rech_date_da       14.814821
# last_rech_amt_ma         3.781141
# cnt_ma_rech30            3.283838
# fr_ma_rech30             1.253275
# sumamnt_ma_rech30        1.080772
# medianamnt_ma_rech30     0.728218
# medianmarechprebal30    14.779840
# cnt_ma_rech90            0.934785
# fr_ma_rech90             1.172472
# sumamnt_ma_rech90        1.126415
# medianamnt_ma_rech90     0.763902
# medianmarechprebal90     0.957942
# cnt_da_rech30           17.818321
# fr_da_rech30            14.776395
# cnt_da_rech90           27.267213
# fr_da_rech90            28.988013
# cnt_loans30              2.713426
# maxamnt_loans30         17.658009
# medianamnt_loans30       4.551031
# cnt_loans90              1.281861
# amnt_loans90             3.149999
# maxamnt_loans90          1.678297
# medianamnt_loans90       4.895707
# ...

# %%
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.cbrt(x[index])
        if x.skew().loc[index]< -0.5:
            x[index]=np.square(x[index])

# %%
x.skew()
# Out:
# aon                     -0.112643
# daily_decr90             0.286481
# rental90                -0.342524
# last_rech_date_ma        0.119354
# last_rech_date_da        5.544190
# last_rech_amt_ma        -0.401959
# cnt_ma_rech30            0.073231
# fr_ma_rech30             0.015890
# sumamnt_ma_rech30       -0.107985
# medianamnt_ma_rech30    -0.001528
# medianmarechprebal30     0.984877
# cnt_ma_rech90            0.428466
# fr_ma_rech90            -0.004881
# sumamnt_ma_rech90       -0.440553
# medianamnt_ma_rech90     0.046514
# medianmarechprebal90    -0.017049
# cnt_da_rech30            7.329725
# fr_da_rech30            11.937087
# cnt_da_rech90            6.010793
# fr_da_rech90            15.500156
# cnt_loans30              0.269110
# maxamnt_loans30         -3.806246
# medianamnt_loans30       3.449034
# cnt_loans90              0.288278
# amnt_loans90            -0.087725
# maxamnt_loans90         -1.655743
# medianamnt_loans90       3.780938
# ...

# %%
img=sns.countplot('label',data=loan)
print(loan["label"].value_counts())
# Out:
# 1    183430
# 0     26162
# Name: label, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
x,y=oversample.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    183430
# 1    183430
# Name: label, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
f=RandomForestClassifier(n_estimators=20, criterion='entropy',random_state=42)
f.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=20, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
pred_decision=rf.predict(x_test)

# %%
y_pred = f.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[34664  1915]
#  [ 1828 34965]]
# 0.9489859892056915
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     36579
#            1       0.95      0.95      0.95     36793
#
#     accuracy                           0.95     73372
#    macro avg       0.95      0.95      0.95     73372
# weighted avg       0.95      0.95      0.95     73372

# %%
metrics.plot_roc_curve(f, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.9489820968291675

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression(max_iter=10000)
lg.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = lg.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[28944  7635]
#  [ 9058 27735]]
# 0.7724881426157117
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78     36579
#            1       0.78      0.75      0.77     36793
#
#     accuracy                           0.77     73372
#    macro avg       0.77      0.77      0.77     73372
# weighted avg       0.77      0.77      0.77     73372

# %%
metrics.plot_roc_curve(lg, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.7725427740041151

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[35624   955]
#  [ 5719 31074]]
# 0.9090388704137818
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91     36579
#            1       0.97      0.84      0.90     36793
#
#     accuracy                           0.91     73372
#    macro avg       0.92      0.91      0.91     73372
# weighted avg       0.92      0.91      0.91     73372

# %%
metrics.plot_roc_curve(knn, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.9190091056927263

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion='entropy')
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = dtc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[33879  2700]
#  [ 3244 33549]]
# 0.9189881698740664
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     36579
#            1       0.93      0.91      0.92     36793
#
#     accuracy                           0.92     73372
#    macro avg       0.92      0.92      0.92     73372
# weighted avg       0.92      0.92      0.92     73372

# %%
metrics.plot_roc_curve(dtc, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.9190091056927263

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_predg = gnb.predict(x_test)
print(confusion_matrix(y_test,y_predg))
print(accuracy_score(y_test,y_predg))
print(classification_report(y_test,y_predg))
# Out:
# [[29264  7315]
#  [11275 25518]]
# 0.7466335931963146
#               precision    recall  f1-score   support
#
#            0       0.72      0.80      0.76     36579
#            1       0.78      0.69      0.73     36793
#
#     accuracy                           0.75     73372
#    macro avg       0.75      0.75      0.75     73372
# weighted avg       0.75      0.75      0.75     73372

# %%
metrics.plot_roc_curve(gnb, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.919004096966453

# %%
svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_preds = svc.predict(x_test)
print(confusion_matrix(y_test,y_preds))
print(accuracy_score(y_test,y_preds))
print(classification_report(y_test,y_preds))
# Out:
# [[32099  4480]
#  [ 5230 31563]]
# 0.8676606880008723
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87     36579
#            1       0.88      0.86      0.87     36793
#
#     accuracy                           0.87     73372
#    macro avg       0.87      0.87      0.87     73372
# weighted avg       0.87      0.87      0.87     73372

# %%
metrics.plot_roc_curve(svc, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.9459256314026829

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='mlogloss', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
y_predg = xgb.predict(x_test)
print(confusion_matrix(y_test,y_predg))
print(accuracy_score(y_test,y_predg))
print(classification_report(y_test,y_predg))
# Out:
# [[34377  2202]
#  [ 1712 35081]]
# 0.9466553998800632
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     36579
#            1       0.94      0.95      0.95     36793
#
#     accuracy                           0.95     73372
#    macro avg       0.95      0.95      0.95     73372
# weighted avg       0.95      0.95      0.95     73372

# %%
metrics.plot_roc_curve(xgb, x_test, y_test)
metrics.roc_auc_score(y_test, y_pred, average=None)
# Out:
# 0.7725427740041151

# %%
import pickle
filename='micro_creditf.pkl'
pickle.dump(f,open(filename,'wb'))

# %%
filename='micro_creditxgb.pkl'
pickle.dump(xgb,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('micro_creditf.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 94.89859892056916

# %%
conclusionf=pd.DataFrame([loaded_model.predict(x_test)[:],y_pred[:]],index=["Predicted","original"])
conclusionf
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      1      0      0      0      1      1      0      1      0
# original       0      0      0      1      1      1      0      1      1
#
#            9      ...  73362  73363  73364  73365  73366  73367  73368  73369  \
# Predicted      0  ...      1      0      1      0      0      1      0      1
# original       1  ...      1      0      1      0      0      1      0      1
#
#            73370  73371
# Predicted      1      1
# original       1      1
#
# [2 rows x 73372 columns]

# %%
loaded_model=pickle.load(open('micro_creditxgb.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 94.66553998800632

# %%
conclusionxgb=pd.DataFrame([loaded_model.predict(x_test)[:],y_predg[:]],index=["Predicted","original"])
conclusionxgb
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      1      0      0      0      1      1      0      1      0
# original       1      0      0      0      1      1      0      1      0
#
#            9      ...  73362  73363  73364  73365  73366  73367  73368  73369  \
# Predicted      0  ...      1      0      1      0      0      1      0      1
# original       0  ...      1      0      1      0      0      1      0      1
#
#            73370  73371
# Predicted      1      1
# original       1      1
#
# [2 rows x 73372 columns]
